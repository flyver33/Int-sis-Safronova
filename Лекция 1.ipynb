# %% [markdown]
# # Интеллектуальные системы

# %% [markdown]
# ## 1. Карты Шухарта

# %% [markdown]
# Гост карт Шухарта — https://docs.cntd.ru/document/1200025672

# %% [markdown]
# ### Пирамида управления.

# %% [markdown]
# Уровень 5. Изобретаются новые методы работы, изменяется работа системы
#
# Уровень 4. Процессы стандратизированы и измеряются
#
# Уровень 3. Процессы в компании стандартизированы
#
# Уровень 2. Появляется небольшая стандартизация: есть некоторые процессы, выполняемые одинаково всеми людьми
#
# Уровень 1. Результат зависит от человека, нет стандартизации

# %% [markdown]
# **Расчёт карт Шухарта.**
# 1. Берём группу элементов одинаковых по значению.
# 2. Усредняем группу.
# 3. Считаем размах (max-min)
# 4. Строим карту:
# ![image.png](attachment:image.png)
